# %%
pwd
# Out:
# '/media/dev/Y_C/Raja/Git/Test'

# %%
ls -al
# Out:
# total 33
# drwxrwxrwx 1 dev dev   448 Mar  7 19:42  ./
# drwxrwxrwx 1 dev dev   496 Mar  7 19:23  ../
# drwxrwxrwx 1 dev dev   448 Mar  7 19:35  .git/
# -rwxrwxrwx 1 dev dev 15873 Mar  7 19:42 'git commands.ipynb'*
# -rwxrwxrwx 1 dev dev  1799 Mar  7 19:06  .gitignore*
# drwxrwxrwx 1 dev dev   192 Mar  7 19:40  .ipynb_checkpoints/
# -rwxrwxrwx 1 dev dev 11357 Mar  7 19:06  LICENSE*
# -rwxrwxrwx 1 dev dev    19 Mar  7 19:06  README.md*
# -rwxrwxrwx 1 dev dev     8 Mar  7 19:33  test2.txt*

# %%
# !man ls
# Out:
# LS(1)                            User Commands                           LS(1)
#
# E
#        ls - list directory contents
#
# S
# E]...
#
# N
#        List  information  about  the FILEs (the current directory by default).
# t  is  speci‐
#        fied.
#
#        Mandatory  arguments  to  long  options are mandatory for short options
#        too.
#
# l
#               do not ignore entries starting with .
#
# l
#               do not list implied . and ..
#
# r
# l, print the author of each file
#
# e
#               print C-style escapes for nongraphic characters
#
# E
# l,  scale  sizes  by  SIZE  when  printing  them;   e.g.,
#               '--block-size=M'; see SIZE format below
#
# s
#               do not list implied entries ending with ~
#
# t: sort by, and show, ctime (time of last modification of
# l: show ctime and sort by  name;
#               otherwise: sort by ctime, newest first
#
# C     list entries by columns
#
# N]
# ...

# %%
# !git status
# Out:
# On branch main
# Your branch is ahead of 'origin/main' by 3 commits.
#   (use "git push" to publish your local commits)
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	git commands.ipynb
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
# !git add
